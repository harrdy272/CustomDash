# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('D:\Events\VIL Codefest\secret\VIL Confidential Information Dataset\Train.csv')
test_df = pd.read_csv('D:\Events\VIL Codefest\secret\VIL Confidential Information Dataset\Test.csv')

# %%
train_df.head()
# Out:
#      Age     ARPU Age on Network Bill Payment Aggregator Brand Identifier  \
# 0  24-28     0-50             24                     NaN         Vodafone
# 1  39-43     0-50             <3                     NaN         Vodafone
# 2  29-33  101-200            >24                     NaN             Idea
# 3    >58     >750          18-24                     NaN         Vodafone
# 4    >58  301-500            3-6                 301-500         Vodafone
#
#   Circle Name Connection Type DND Service  DND Status Data Usage  ...  \
# 0     Kolkata         Prepaid           N         NaN      10-15  ...
# 1     Kolkata         Prepaid           N         NaN         <1  ...
# 2       Delhi         Prepaid         NaN  ACTIVE_DND      10-15  ...
# 3      Mumbai         Prepaid           Y         NaN        >15  ...
# 4     Kolkata        Postpaid           N         NaN      10-15  ...
#
#            Genre            ID International Usage OTT Content App   Pincode  \
# 0    Game Series  VFMUKOL38741                 NaN             Yes  700040.0
# 1  Marathi Drama  VFMUKOL54162                 NaN             Yes  700038.0
# 2  Marathi Drama   IDKRDL59718                 NaN             Yes  110053.0
# 3    Game Series   VFMUKOL5295                 Yes             Yes  410218.0
# 4  Marathi Drama  VFMUKOL60365                 NaN             Yes  700091.0
#
#    Recharge SMS Usage      VAS Subscription Voice Usage   Web/App
# 0  501-1000    51-100  HOICHOI PARTNER PACK     501-750  Non_User
# 1   101-300      1-25                   NaN    751-1000  Non_User
# 2   101-200      1-25                   NaN       >1000  Non_User
# 3   201-300      1-25                   NaN     501-750  Non_User
# 4       NaN     26-50  HOICHOI PARTNER PACK     501-750  Non_User
#
# [5 rows x 21 columns]

# %%
train_df.isnull().sum()
# Out:
# Age                          2824
# ARPU                            0
# Age on Network               1361
# Bill Payment Aggregator    100264
# Brand Identifier                0
# Circle Name                     0
# Connection Type                 0
# DND Service                 56393
# DND Status                  56196
# Data Usage                      0
# Gender                       3288
# Genre                           0
# ID                              0
# International Usage        107735
# OTT Content App                 0
# Pincode                      2535
# Recharge                    27715
# SMS Usage                       0
# VAS Subscription            80286
# Voice Usage                     0
# Web/App                         0
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# Age                         1175
# ARPU                           0
# Age on Network               585
# Bill Payment Aggregator    43071
# Brand Identifier               0
# Circle Name                    0
# Connection Type                0
# DND Service                24191
# DND Status                 24062
# Data Usage                     0
# Gender                      1421
# Genre                          0
# ID                             0
# International Usage        46220
# OTT Content App                0
# Pincode                     1087
# Recharge                   11743
# SMS Usage                      0
# VAS Subscription           34404
# Voice Usage                    0
# Web/App                        0
# dtype: int64

# %%
train_df[train_df['Recharge'].isna()]['Recharge']
# Out:
# 4         NaN
# 11        NaN
# 24        NaN
# 25        NaN
# 28        NaN
#          ...
# 112565    NaN
# 112574    NaN
# 112582    NaN
# 112583    NaN
# 112588    NaN
# Name: Recharge, Length: 27715, dtype: object
